# %% [markdown]
# <a href="https://colab.research.google.com/github/yosoyprisca/rconcolab/blob/master/.ipynb_checkpoints/datosTabulares-checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![conocilogo.png](data:image/png;base64,...)
#
#
# Carlos Alberto Peralta Alvarez 2025 | GPL3
#
# Importación y exportación de archivos
# Iteración
# Operaciones estadísticas?
# manipulación de datos tabulares

# %% [markdown]
# ## ☝ Navegación del directorio de trabajo
#
# R tiene un directorio de trabajo default que cambia entre sistemas operativos, sin embargo para conocerlo y llegar a cambiarlo tenemos varias funciones que nos ayudan.
#
# ```
# getwd() # Nos permite conocer el directorio de trabajo actual
#
# setwd("path/al/directorio/deseado") # Cambia el directorio (Linux/Mac/COLAB)
#
# # Cuando usamos Colab estamos usando Linux! 🐧
#
# setwd("C:path\al\directorio") # Versión para Windows
# ```
#
# Podemos listar los directorios o archivos del directorio actual (de trabajo) o de algun otro.
#
# La manera mas sencilla es utilizar `list.files()`
#
# ```
# list.files() # sin argumentos: lista los archivos y carpetas del directorio de trabajo.
#
# list.files("path/al/directorio") # devuelve la información para el directorio solicitado, en Windows reemplazamos / por \
# ```
#
# Otro comando útil es `list.dirs()` funciona de forma similar al anterior pero únicamente muestra carpetas (folders ó directorios) de forma recursiva e incluye aquellos que se encuentran ocultos.

# %% [markdown]
# ## ☝ Importar datos a Colab
#
# Seleccionaremos el ícono de los archivos
#
# ![image.png](data:image/png;base64,...)
#
# A continuación daremos click en subir archivos
#
# ![image.png](data:image/png;base64,...)
#
# En nuestra computadora navegamos hasta los archivos de nuestro interés y los cargaremos.
#
# **Es importante saber que es un almacenamiento temporal y que debemos respaldar todo lo que carguemos a Colab o creemos en Colab.**
#
# Al concluir el proceso de subida, los archivos deben aparecer listados en el explorador
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ⏰ __Ejercicio__ Descarga de Github los datos de la carpeta _biodatos_ y súbelos a Colab
#
# [Enlace](https://github.com/cperalta22/bioinfoRmatica/tree/main/biodatos) a los datos
#
# Recuérda que hay que dar click en cada uno de los archivos
#
# ![image.png](data:image/png;base64,...)
#
# Y posteriormente en la página que se abre buscar el botón de descargas.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ☝ Leer un archivo de texto
#
# La forma más sencilla de leer un archivo es con `readLines()` nota la L mayúscula en el nombre de la función
#
# `readLines("path/al/archivo")`
#
# Si el archivo está en nuestro directorio de trabajo podemos leerlo sin especificar todo el path, simplemente por su nombre y extensión
#
# ```
# readLines("genes_hiccups_loops1.bed")
# ```
#
# Recuerda que siempre podemos usar otros vectores para facilitarnos la vida.
#
# por otro lado la función `head()` nos permite ver únicamente la parte inicial de archivos muy grandes, para ver la parte final usamos `tail()`
#
# ```
# readLines(list.files()[2]) |> head()
# ```

# %%
list.files()

#readLines("genes_hiccups_loops1.bed")

#readLines(list.files()[2]) |> head()

# %% [markdown]
# ## ☝ Archivos separados por delimitadores
#
# En bioinformática usamos archivos en texto plano (no en Excel o Word), por que permite mantener su tamaño reducido y maximizar la compatibilidad.
#
# Delimitadores mas frecuentes:
#
# |Caracter|Nombre|Nombre genérico de los archivos|Extensión|
# |:-:|:-:|:-:|:-:|
# |,|Coma|Archivo separado por comas|.csv|
# |\\t|Tabulador|Archivo separado por tabuladores|.tsv|
# |;|Punto y coma _semicolon_||a veces .csv, pero varía|
# |(varía)|Espacio en blanco||casi siempre .txt|
#
# En bioinformática casi siempre serán los dos primeros por la facilidad para su uso.
#
# Aunque no tienen las extensiones mencionadas, nuestros archivos de ejemplo están separados por comas (archivo con extensión .bed) y por tabuladores (archivo con extensión .tabular)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 🤔 De excel a R (ó a Python)
#
# *   Hay librerias que permiten la importación directa
# *   Es más facil salvar como un CSV ó TSV en excel y abrir en R
# *   Importante sólo guardar lo que nos interesa como tabla
#
# Por ejemplo una hoja como esta:
#
# ![image.png](data:image/png;base64,...)
#
# le quitaremos todo lo que sean imágenes y columnas y filas vacías . . .
#
# ![image.png](data:image/png;base64,...)
#
# Nota cómo quedaron los datos en el extremo superiór izquierdo, entonces si los exportamos como CSV ó TSV

# %% [markdown]
# ## ☝ El Tidyverse
#
# Es una **colección** de librerias que mejoran la experiencia por defecto de R para:
#
#
# *   Manejo de datos tabulares
# *   Visualización de los datos
# *   Manipulación de cadenas de texto
#
#
# [ver más](https://es.wikipedia.org/wiki/Tidyverse)
#
# Instalémoslo de una sóla vez con:
#
# `install.packages('tidyverse')`
#
# y lo cargamos en memoria con la función `library(tidyverse)`
#
# 💡 **Es muy importante tener en cuenta que todo lo relacionado al tidyverse utiliza con mucha frecuencia el entubamiento (`|>`) por lo que debemos estar preparados para utilizar esta forma de programar.**

# %%
install.packages('tidyverse')

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.0     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.2     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
read.csv #en R
read_csv #en tidyverse
#no son intercambaibles, usan distintos argumentos ehhhh

# %% [markdown]
# ## ☝Importémos los datos como un par de data frames . . . quiero decir _tibbles_
#
# El archivo con extensión .bed es un archivo separado por comas por lo que utilizaremos la función del __tidyverse__ `read_csv("genes_hiccups_loops1.bed")`
#
# Es mucho más práctico asignar el resultado de esta operación a un nuevo objeto, este será un Tibble, en la práctica es indistinguible de un Data Frame.
#
# Podemos explorar su contenido al usar algunas funciones útiles:
#
# |Función|Acción|
# |-|-|
# |`head()` y `tail()`|Muestran los extremos superior e inferior respectivamente|
# |`glimpse()`| Nos dá información útil sobre el contenido y tipo de datos de la tabla|
# |`nrow()` y `ncol()`| Regresa el numero de filas y de columnas respectivamente |
# |`rownames()` y `colnames()` | Regresa los nombres asociados filas y columnas |
#
#
# Conociendo sin conocer el nombre de las filas o las columnas, podemos acceder a los datos con los corchetes cuadrados, pero conociendo los datos de los nombres nosotros podemos usar el caracter `$` para llamar a las columnas por su nombre.

# %%
genes <- read_csv("genes_hiccups_loops1.bed")

glimpse(genes)

colnames(genes)

# %%
genes <- read_csv("genes_hiccups_loops1.bed", col_names = F)

glimpse(genes)

colnames(genes)
# Out:
# Rows: 1119 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): X1, X4
# dbl (2): X2, X3
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1,119
# Columns: 4
# $ X1 <chr> "chr1", "chr1", "chr1", "chr1", "chr1", "chr1", "chr1", "chr1", "ch…
# $ X2 <dbl> 13050000, 19105000, 19210000, 19100000, 36555000, 36690000, 3727000…
# $ X3 <dbl> 13055000, 19110000, 19215000, 19105000, 36560000, 36695000, 3727500…
# $ X4 <chr> "Gm37162", "Tfap2d", "Tfap2b", "Tfap2d", "Sema4c", "Cox5b", "170007…
# [1] "X1" "X2" "X3" "X4"

# %%
genes |> head()

genes$X1 |> head()

genes$X1 |> unique()

# %% [markdown]
# ## ☝Reemplazemos los nombres de las columnas
#
# Aqui es muy útil la función `colnames()` en conjunto con el operador de asignación `<-` y un vector del mismo tamaño que el número de columnas
#
# Ejemplo:
# ```
# colnames(genes) <- c("cromosoma","inicio","final", "nombre")
# ```

# %%
colnames(genes) <- c("cromosoma","inicio", "final", "nombre")

glimpse(genes)
# Out:
# Rows: 1,119
# Columns: 4
# $ cromosoma <chr> "chr1", "chr1", "chr1", "chr1", "chr1", "chr1", "chr1", "chr…
# $ inicio    <dbl> 13050000, 19105000, 19210000, 19100000, 36555000, 36690000, …
# $ final     <dbl> 13055000, 19110000, 19215000, 19105000, 36560000, 36695000, …
# $ nombre    <chr> "Gm37162", "Tfap2d", "Tfap2b", "Tfap2d", "Sema4c", "Cox5b", …

# %% [markdown]
# ## ☝ Creación de nuevas columnas
#
# La funcion `mutate()` nos ayuda en este aspecto.
#
# Es una función del **tidyverse** y en este ecosistema de funciones siempre podemos usar el operador `|>` para pasar la salida de un primer comando a los sucesivos.

# %%
genes2 <- genes |> mutate(regionSize = final-inicio)

head(genes2)
# Out:
#   cromosoma inicio   final    nombre  regionSize
# 1 chr1      13050000 13055000 Gm37162 5000
# 2 chr1      19105000 19110000 Tfap2d  5000
# 3 chr1      19210000 19215000 Tfap2b  5000
# 4 chr1      19100000 19105000 Tfap2d  5000
# 5 chr1      36555000 36560000 Sema4c  5000
# 6 chr1      36690000 36695000 Cox5b   5000

# %% [markdown]
# Puedo hacer mas de una columna a la vez
#
# Aqui lo combinamos con una poderosa herramienta del tidyverse; la colección de funciones llamadas `stringr`
#
# Dos de las funciones que usaremos frecuentemente en bioinformática es el eliminar partes de un texto o sustituirlo por otro, hagámoslo con`str_remove()` , `str_remove_all()`  , `str_replace()`  y `str_replace_all()`

# %%
genes2 <- genes |>
  mutate(regionSize = final - inicio,chrNumber = str_remove(cromosoma, 'chr'), Cromosoma = str_replace(cromosoma, "chr", "Chr"))

head(genes2)
# Out:
#   cromosoma inicio   final    nombre  regionSize chrNumber Cromosoma
# 1 chr1      13050000 13055000 Gm37162 5000       1         Chr1
# 2 chr1      19105000 19110000 Tfap2d  5000       1         Chr1
# 3 chr1      19210000 19215000 Tfap2b  5000       1         Chr1
# 4 chr1      19100000 19105000 Tfap2d  5000       1         Chr1
# 5 chr1      36555000 36560000 Sema4c  5000       1         Chr1
# 6 chr1      36690000 36695000 Cox5b   5000       1         Chr1

# %% [markdown]
# Obtener información relevante de la tabla es sencillo si usamos funciones para resumir, una muy sencilla es `table()`

# %%
table(genes2$regionSize)
tail(genes2$regionSize)

boxplot(genes2$inicio)
boxplot(genes2$regionSize)
# Out:
# 5000
# 1119
# [1] 5000 5000 5000 5000 5000 5000
# plot without title
# plot without title

# %%
table(genes2$nombre)
# Out:
# 1010001N08Rik 1110002J07Rik 1110008L16Rik 1110051M20Rik 1600002K03Rik
#             1             1             1             1             1
# 1700015F17Rik 1700021A07Rik 1700031A10Rik 1700041G16Rik 1700074A21Rik
#             1             1             1             1             1
# 2010107G23Rik 2010111I01Rik 2310065F04Rik 2410015M20Rik 2700060E02Rik
#             1             1             1             1             1
# 2900052N01Rik 4930429P21Rik 4930467K11Rik 4930524O08Rik 4930532M18Rik
#             1             1             1             1             1
# 4930544L04Rik 4930550C17Rik 4930573C15Rik 4930588K23Rik 4933406D12Rik
#             1             1             1             1             2
# 4933416M07Rik 4933427D06Rik 4933431C10Rik 5430427N15Rik 5430433H01Rik
#             1             1             1             1             1
# 6030445D17Rik 6430584L05Rik 6430628N08Rik 8430419K02Rik 9130019P16Rik
#             1             1             2             1             1
# 9130410C08Rik 9530018H14Rik 9930104L06Rik A330074H02Rik A430105J06Rik
#             1             1             1             1             1
# A930002I21Rik A930004D18Rik A930015D03Rik         Aaed1         Abcb8
#             1             1             1             1             1
#         Abcg1          Abl1          Abl2         Acaa2         Acacb
#             1             1             1             1             1
#         Acot7          Actb       Adamts8        Adgrb1        Adgrf1
#             1             1             1             1             1
#        Adgrg7         Afap1       Afap1l2         Aggf1        Agpat4
#             1             1             1             1             1
#        Ahcyl1         Ahdc1         Ahnak          Aif1          Aim1
#             1             1             1             1             1
#         Akap7       Aldh8a1        Alkbh1         Alox8          Alx4
#             1             1             1             1             1
#          Ank3       Ankrd63       Ankrd66        Anks1b         Ap2s1
#             1             2             1             1             1
#       Apc-ps1          Apeh          Apip         Aplnr         Apmap
#             1             1             1             1             1
#         Aqp11          Aqp6         Arap3          Arf1      Arhgap22
#             1             1             1             1             1
#      Arhgap23      Arhgap40         Arl4d         Armc9          Asb4
#             1             2             2             2             1
#        Atp5g2       Atxn7l3      AW047730           Axl      AY512931
#             1             1             1             1             1
#          Aym1 B230206L02Rik      B4galnt3          Bag6        Barhl1
#             1             1             1             1             2
#        Barhl2         Barx1         Baz1b         Baz2a         Bcas1
#             2             1             1             1             1
#      Bcas3os1          Bcor         Birc7           Blk          Bmi1
#             1             3             1             1             1
#        Bpifb5         Btnl9          Bzw1 C030014I23Rik C130032M10Rik
#             1             1             1             1             1
# C130071C03Rik          C1qa         C1ql2 C230035I16Rik C630050I24Rik
#             1             2             1             2             1
#        Cabin1       Cables2       Cacna1e         Calm3          Caly
#             1             1             2             1             1
#        Camk2a        Camk2b        Camk2g        Camta1         Casz1
#             1             1             1             1             1
#          Cblc          Cbx4          Cbx7          Cbx8        Ccdc33
#             2             1             1             3             1
#        Ccdc68        Ccdc97           Cck          Ccl1         Ccnd1
#             1             1             1             1             1
#         Ccnd2          Cct4         Cd164         Cd24a          Cd40
#             2             1             1             1             1
#           Cd9         Cdh23         Cdk18       Cdk3-ps        Cdk5r2
#             1             2             1             1             1
#      Cdk5rap1      Cdk5rap3          Cdk9        Cdkn2c         Cebpb
#             1             1             1             1             1
#        Celsr3         Cep68         Cerkl       Cfap157           Cfd
#             1             1             1             1             1
#         Cgnl1         Chia1         Chit1         Chmp5          Chn2
#             1             1             1             1             1
#        Chrna3         Chrne        Chst15         Chst8         Chsy1
#             1             1             1             1             1
#           Ckb        Clasp1         Clic4         Clip2         Cnnm2
#             1             1             1             1             1
#      Cntrobos       Col13a1       Col14a1       Col18a1       Col20a1
#             1             4             1             1             1
#          Comp        Coro2b         Cox5b        Cox7a1         Cpne5
#             1             1             1             1             1
#        Cpsf4l       Creb3l1       Creb3l2        Crocc2        Cryba2
#             1             1             2             1             1
#        Cryba4         Ctbp1          Ctc1         Ctdp1          Cttn
#             1             1             1             1             1
#          Cux1         Cwh43        Cxcl14       Cyp17a1       Cyp26a1
#             1             1             1             1             1
#       Cyp26b1        Cystm1 D130051D11Rik D330050G23Rik D830044D21Rik
#             1             1             1             1             1
#        Dab2ip          Dbx1         Dcdc5         Dcp1b          Ddb1
#             3             1             1             1             1
#           Ddc         Ddx10         Ddx11         Ddx54        Defb25
#             1             1             1             1             1
#          Dgki         Dhcr7          Dhx8          Dis3          Dlx1
#             2             1             1             1             2
#          Dlx3          Dlx6         Dmrt3        Dnaic2       Dnajc11
#             1             1             1             1             1
#          Dnm1        Dnmt3a          Dok4          Drg1         Dscr3
#             1             1             1             1             1
#         Dusp9       Dync1i1          Ece1        Echdc3         Eef2k
#             1             1             1             1             1
#       Efcab10        Efcab5         Eif1a         Eif4b          Elf5
#             1             1             1             1             1
#         Elmo1        Elmod1           En2          Enah          Enc1
#             1             1             2             1             1
#         Ephb2         Ephb3          Erc2          Evx2 F630040K05Rik
#             1             1             1             1             1
#          Fadd       Fam179a       Fam184b       Fam205c       Fam220a
#             2             2             1             1             1
#         Fbln1         Fbln2         Fcrlb          Fgf1          Fgf4
#             1             1             1             2             1
#          Fhl2         Flot1          Fmod           Fos         Foxa1
#             1             1             1             1             1
#         Foxd1         Foxd2         Foxd4         Foxf1         Foxf2
#             2             1             1             1             1
#         Foxk1         Foxq1         Frem2         Frrs1         Fscn1
#             2             1             1             1             2
#        Gabbr1       Gadd45b       Gadd45g        Galnt1        Gas2l3
#             1             1             1             1             1
#         Gata3         Gdpd5          Gfap        Ggnbp1          Ggt7
#  RP23-453P1.1 RP24-130A20.1 RP24-133K20.5  RP24-202L5.3 RP24-354I16.2
#             1             1             1             1             1
#          Rpa2          Rpia    Rpl21-ps11         Rpl26     Rpl27-ps2
#             1             1             1             1             1
#     Rpl36-ps4        Rpl37a         Rplp1        Rpp25l     Rps13-ps5
#             1             1             1             1             1
#         Rps19      Rps2-ps5          Rps5         Rraga       Rtn4ip1
#             1             1             1             1             1
#       Rtn4rl1       S100a10        Scara5        Scarf2          Scd1
#             1             1             1             1             1
#          Scd3       Scgb1c1        Scnn1g         Sdad1          Sdc3
#             2             2             1             1             1
#        Sema3f        Sema4c        Sema4f        Sema5b        Sema7a
#             1             1             1             1             1
#         Senp3         Sept5         Sept9      Serpinh1          Sez6
#             1             1             2             1             1
#         Sfxn1        Sh2d4b        Sh3tc1       Sipa1l3          Six1
#             2             1             1             1             1
#       Six3os1        Skida1       Slc10a1       Slc17a7       Slc22a4
#             1             1             1             1             1
#        Slc2a3       Slc36a1       Slc44a3       Slc44a5       Slc5a11
#             2             1             1             1             1
#        Slc8b1       Slco1c1       Slco4a1         Slit1         Slmo1
#             2             1             1             2             1
#         Smad6        Smim24        Snhg20       Snora30       Snord12
#             1             1             1             1             1
#      Snrnp200       Snrnp25         Snx11         Snx19         Soat2
#             1             1             1             2             1
#         Socs6         Sorl1         Sox13           Sp2           Sp5
#             1             1             1             1             1
#           Sp9         Sparc       Spdye4b        Specc1        Spesp1
#             1             1             1             2             1
#        Spint1        Srebf2          Srgn         Srrm2         Srrm3
#             1             1             2             1             1
#         Srsf3         Stk11          Sv2b         Synpo          Tab2
#             2             1             1             1             1
#          Tal1          Tank          Tars        Tas1r2         Tbata
#             1             1             1             1             1
#       Tbc1d14          Tbx3          Tcf3         Tcof1         Tcp11
#             1             1             1             1             1
#         Tctn1       Teddm1a         Tekt4          Tesc         Tesk2
#             1             1             1             1             1
#        Tfap2b        Tfap2d          Tfpi          Tfrc            Tg
#             1             2             1             1             2
#          Thy1         Tiam2          Tjp2         Tldc1        Tlx1os
#             1             1             1             1             1
#          Tmc5       Tmcc3os        Tmed10       Tmem107       Tmem108
#             1             1             1             1             1
#       Tmem136       Tmem216       Tmem220       Tmem221        Tmem8c
#             2             1             2             2             1
#      Tmprss13       Tmprss9      Tnfrsf21        Tnfsf9         Tnip1
#             2             1             1             1             1
#         Top2a          Tox2         Tpd52         Tra2a       Trappc9
#             1             1             1             2             1
#        Trim56        Trim60          Trmo          Trmu         Trpm5
#             1             1             1             2             1
#          Tsku        Ttc39b          Ttf2         Tubb3       Tubgcp3
#             1             1             1             1             1
#         Tulp1      Tvp23bos        Txnrd2          Ubtf         Uevld
#             1             1             1             2             2
#          Ulk1        Unc119          Uncx          Upf2         Upf3a
#             1             1             2             1             1
#          Upk2         Uqcc1          Urb2         Usp10         Usp43
#             1             1             1             1             1
#         Utp23         Vamp1          Vav2          Vax2         Vgll4
#             1             1             1             1             1
#        Vps13d         Wbp1l       Wbscr28         Wdr61         Wdr63
#             1             1             1             1             1
#         Wdr75         Wisp1        Wnt10a        Wnt10b          Wnt3
#             1             1             3             3             1
#          Wnt6         Wnt9a          Wsb2           Wt1      Xrcc6bp1
#             2             1             1             1             1
#          Yars         Ypel5        Zbtb21        Zbtb32        Zbtb40
#             1             1             1             1             1
#        Zbtb45       Zbtb8os       Zdhhc19       Zfp385c        Zfp664
#             1             1             1             1             1
#        Zfp692        Zfp703         Zfp78        Zfp936         Zfpm1
#             1             1             2             1             1
#          Zic1          Zic4        Zmynd8        Znhit3           Zp2
#             1             1             1             1             1

# %% [markdown]
# ## ⏰ __Ejercicio__ Haz un resumen de las regiones por cromosoma
#
# tip: usa `table()`

# %%
table(genes2$cromosoma)
# Out:
#  chr1 chr10 chr11 chr12 chr13 chr14 chr15 chr16 chr17 chr18 chr19  chr2  chr3
#    67    52   133    28    43    22    50    29    37    29    48   117    34
#  chr4  chr5  chr6  chr7  chr8  chr9  chrX
#    73    83    63   102    43    58     8

# %% [markdown]
# ## ☝ Filtrar y seleccionar columnas de interés
#
# `filter()` nos permite usar __comparaciones lógicas__ para seleccionar únicamente las filas de nuestro interés.
#
# `select()` nos deja usar las columnas que necesitamos.
#
# `arrange()` nos facilita ordenar los datos por una columna en particular

# %%
genes3 <- genes2 |>
  filter(cromosoma == 'chr1') |>
  select(c(nombre,Cromosoma,inicio,final))

head(genes3)
# Out:
#   nombre  Cromosoma inicio   final
# 1 Gm37162 Chr1      13050000 13055000
# 2 Tfap2d  Chr1      19105000 19110000
# 3 Tfap2b  Chr1      19210000 19215000
# 4 Tfap2d  Chr1      19100000 19105000
# 5 Sema4c  Chr1      36555000 36560000
# 6 Cox5b   Chr1      36690000 36695000

# %%
colnames(genes2)
head(genes2)
# Out:
# [1] "cromosoma"  "inicio"     "final"      "nombre"     "regionSize"
# [6] "chrNumber"  "Cromosoma"
#   cromosoma inicio   final    nombre  regionSize chrNumber Cromosoma
# 1 chr1      13050000 13055000 Gm37162 5000       1         Chr1
# 2 chr1      19105000 19110000 Tfap2d  5000       1         Chr1
# 3 chr1      19210000 19215000 Tfap2b  5000       1         Chr1
# 4 chr1      19100000 19105000 Tfap2d  5000       1         Chr1
# 5 chr1      36555000 36560000 Sema4c  5000       1         Chr1
# 6 chr1      36690000 36695000 Cox5b   5000       1         Chr1

# %%
genes3 <- genes2 |>
  filter(cromosoma == 'chr1') |>
  select(c(nombre,final)) |>
  arrange(nombre,desc(final))
#el orden de select es el que tendré en mis resultados

#estructura: llamar objeto tabular, pasarlo a una serie de funciones sin ya poner el $
#porfque ya son objetos que pueden llamar de manera directa, no lleva comillas
#
head(genes3)
# Out:
#   nombre        final
# 1 1700074A21Rik  37275000
# 2 4930532M18Rik 154285000
# 3 A430105J06Rik 186830000
# 4 Abl2          156635000
# 5 Armc9          86225000
# 6 Armc9          86180000

# %% [markdown]
# Una forma mas sofisticada y que nos permite trabajar con la información resumida es usar las funciones `group_by()` y `summarise()` de manera combinada

# %%
genes4 <- genes2 |> group_by(nombre) |> summarise(ocurrencias = n())
# te decvuelve una cosa diferente al original, pq summarise es destructivo
#

head(genes4)
nrow(genes4)
# Out:
#   nombre        ocurrencias
# 1 1010001N08Rik 1
# 2 1110002J07Rik 1
# 3 1110008L16Rik 1
# 4 1110051M20Rik 1
# 5 1600002K03Rik 1
# 6 1700015F17Rik 1
# [1] 985

# %%
genes4 <- genes2 |> group_by(nombre) |> summarise(ocurrencias = n()) |> filter(ocurrencias > 1)

head(genes4)
nrow(genes4)
# Out:
#   nombre        ocurrencias
# 1 4933406D12Rik 2
# 2 6430628N08Rik 2
# 3 Ankrd63       2
# 4 Arhgap40      2
# 5 Arl4d         2
# 6 Armc9         2
# [1] 117

# %% [markdown]
# ## 🥳 __Ejercicio Final__
#
# Encuentra los genes con expresión diferencial
#
# El archivo __edgeR_EPREC-HSPC_unfiltered.tabular__ contiene datos sin filtrar de la comparación de dos muestras de RNA-Seq.
#
# Lo que nos interesa es conocer los genes que cambiaron su expresión de manera significativa, es decir que su valor de expresión __aumentó o disminuyó__ en mas de logFC 1.5 ó menos de logFC -1.5.
#
# Además para considerarlos estadísticamente significativos dichos genes deberán tener un FDR inferior a 0.01.
#
# En el archivo hay columnas correspondientes tanto a __logFC__ cómo __FDR__
#
# Debes cumplir con lo siguiente:
#
# Filtrar la tabla para quedarte únicamente con los genes que se subexpresan o sobreexpresan de acuerdo a los criterios de arriba.
#
# guardar en un vector, data frame o una versión filtrada del tibble los genes sobreexpresados y en otro objeto similar los subexpresados.
#
# Suerte!

# %%
expdif <- read_tsv("edgeR_EPREC-HSPC_unfiltered.tabular")

head(expdif)

glimpse(expdif)
# Out:
# Rows: 28265 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): GeneID
# dbl (5): logFC, logCPM, F, PValue, FDR
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   GeneID logFC     logCPM    F        PValue        FDR
# 1 HBM    15.446471 10.412520 2183.623  0.000000e+00  0.000000e+00
# 2 HBA2   15.355375 10.321403 2116.292  0.000000e+00  0.000000e+00
# 3 HBG1   11.168411 12.623988 3977.954  0.000000e+00  0.000000e+00
# 4 AHSP   11.167012 12.713144 4068.657  0.000000e+00  0.000000e+00
# 5 PRDX2   7.543826 11.093705 1963.391  0.000000e+00  0.000000e+00
# 6 FTH1    6.681510  9.794284 1188.231 1.051873e-257 4.955197e-254
# Rows: 28,265
# Columns: 6
# $ GeneID <chr> "HBM", "HBA2", "HBG1", "AHSP", "PRDX2", "FTH1", "NMU", "MPC2", …
# $ logFC  <dbl> 15.446471, 15.355375, 11.168411, 11.167012, 7.543826, 6.681510,…
# $ logCPM <dbl> 10.412520, 10.321403, 12.623988, 12.713144, 11.093705, 9.794284…
# $ F      <dbl> 2183.6234, 2116.2919, 3977.9536, 4068.6572, 1963.3910, 1188.230…
# $ PValue <dbl> 0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00, 0.00000…
# $ FDR    <dbl> 0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00, 0.00000…
